# %%
import pandas as pd

# %%
df = pd.read_csv('glassdoor_jobs.csv')

# %% [markdown]
# ### Salary Parsing

# %%
# getting rid of None values
df = df[df['Salary Estimate'] != '-1']

# %%
# looking for a Per Hour salary and creating a new column to identify it 
df['Hourly'] = df['Salary Estimate'].apply(lambda x: 1 if '/hr' in x.lower() else 0)
# creating a variable to take only the numeric value
salary = df['Salary Estimate'].apply(lambda x: x.split('/')[0])
# creating a new column to store the clean salary value and getting rid of other simbols
df['upd_salary'] = salary.apply(lambda x: x.replace('$', '').replace(',', '').replace(' ', ''))
# changing the salary value type to float
df['upd_salary'] = df['upd_salary'].apply(lambda x: float(x))

# %%
df
# Out:
#                                         Job Title      Salary Estimate  \
# 0                   Data Scientist (Level I - II)   $91,036 /yr (est.)
# 1                                  Data Scientist  $110,000 /yr (est.)
# 4                                  Data Scientist    $65.71 /hr (est.)
# 5                        Data Scientist - Virtual   $96,225 /yr (est.)
# 6        Entry level Data Science Engineer-333338   $62,500 /yr (est.)
# ..                                            ...                  ...
# 993  data scientist, Operational Excellence - GSC  $124,950 /yr (est.)
# 994                                Data Scientist  $110,000 /yr (est.)
# 995              Data Scientist, Machine Learning  $114,296 /yr (est.)
# 996    Data Scientist / Machine Learning Engineer  $130,867 /yr (est.)
# 997                      Data Scientist - Virtual   $96,225 /yr (est.)
#
#      Rating           Company Name        Location  Headquarters  \
# 0       3.5    BEN Group, Inc\n3.5       Provo, UT            -1
# 1       4.6    Super Dispatch\n4.6          Remote            -1
# 4      -1.0       Biometric Health     Jackson, MS            -1
# 5       4.2     Vizient, Inc.\n4.2          Remote            -1
# 6       4.2  I28 Technologies\n4.2  Marysville, MI            -1
# ..      ...                    ...             ...           ...
# 993     3.7         Starbucks\n3.7     Seattle, WA            -1
# 994     4.6    Super Dispatch\n4.6          Remote            -1
# 995     5.0    Locus Robotics\n5.0  Wilmington, MA            -1
# 996     4.6        Databricks\n4.6        West, TX            -1
# 997     4.2     Vizient, Inc.\n4.2          Remote            -1
#
#                        Size  Founded  Type of ownership  \
# 0      201 to 500 Employees     2014  Company - Private
# 1       51 to 200 Employees       -1  Company - Private
# 4                   Unknown       -1                 -1
# 5    1001 to 5000 Employees       -1  Company - Private
# 6         1 to 50 Employees       -1  Company - Private
# ..                      ...      ...                ...
# 993        10000+ Employees       -1                 -1
# 994     51 to 200 Employees       -1  Company - Private
# 995    201 to 500 Employees       -1  Company - Private
# 996  1001 to 5000 Employees       -1  Company - Private
# 997  1001 to 5000 Employees       -1  Company - Private
#
#                            Industry                 Sector  \
# 0    Advertising & Public Relations  Media & Communication
# 1                                -1                     -1
# 4                                -1                     -1
# 5                                -1                     -1
# 6                                -1                     -1
# ..                              ...                    ...
# 993                              -1                     -1
# 994                              -1                     -1
# 995                              -1                     -1
# 996                              -1                     -1
# 997                              -1                     -1
#
#                        Revenue  Competitors  Hourly  upd_salary
# 0    $25 to $100 million (USD)           -1       0    91036.00
# 1                           -1           -1       0   110000.00
# 4                           -1           -1       1       65.71
# 5                           -1           -1       0    96225.00
# 6                           -1           -1       0    62500.00
# ..                         ...          ...     ...         ...
# 993                         -1           -1       0   124950.00
# 994                         -1           -1       0   110000.00
# 995                         -1           -1       0   114296.00
# 996                         -1           -1       0   130867.00
# 997                         -1           -1       0    96225.00
#
# [818 rows x 15 columns]

# %% [markdown]
# ### Company name text only

# %%
# Removing the last four characters of the Company Name where the rating is added
df['Company text'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-4], axis = 1)
df
# Out:
#                                         Job Title      Salary Estimate  \
# 0                   Data Scientist (Level I - II)   $91,036 /yr (est.)
# 1                                  Data Scientist  $110,000 /yr (est.)
# 4                                  Data Scientist    $65.71 /hr (est.)
# 5                        Data Scientist - Virtual   $96,225 /yr (est.)
# 6        Entry level Data Science Engineer-333338   $62,500 /yr (est.)
# ..                                            ...                  ...
# 993  data scientist, Operational Excellence - GSC  $124,950 /yr (est.)
# 994                                Data Scientist  $110,000 /yr (est.)
# 995              Data Scientist, Machine Learning  $114,296 /yr (est.)
# 996    Data Scientist / Machine Learning Engineer  $130,867 /yr (est.)
# 997                      Data Scientist - Virtual   $96,225 /yr (est.)
#
#      Rating           Company Name        Location  Headquarters  \
# 0       3.5    BEN Group, Inc\n3.5       Provo, UT            -1
# 1       4.6    Super Dispatch\n4.6          Remote            -1
# 4      -1.0       Biometric Health     Jackson, MS            -1
# 5       4.2     Vizient, Inc.\n4.2          Remote            -1
# 6       4.2  I28 Technologies\n4.2  Marysville, MI            -1
# ..      ...                    ...             ...           ...
# 993     3.7         Starbucks\n3.7     Seattle, WA            -1
# 994     4.6    Super Dispatch\n4.6          Remote            -1
# 995     5.0    Locus Robotics\n5.0  Wilmington, MA            -1
# 996     4.6        Databricks\n4.6        West, TX            -1
# 997     4.2     Vizient, Inc.\n4.2          Remote            -1
#
#                        Size  Founded  Type of ownership  \
# 0      201 to 500 Employees     2014  Company - Private
# 1       51 to 200 Employees       -1  Company - Private
# 4                   Unknown       -1                 -1
# 5    1001 to 5000 Employees       -1  Company - Private
# 6         1 to 50 Employees       -1  Company - Private
# ..                      ...      ...                ...
# 993        10000+ Employees       -1                 -1
# 994     51 to 200 Employees       -1  Company - Private
# 995    201 to 500 Employees       -1  Company - Private
# 996  1001 to 5000 Employees       -1  Company - Private
# 997  1001 to 5000 Employees       -1  Company - Private
#
#                            Industry                 Sector  \
# 0    Advertising & Public Relations  Media & Communication
# 1                                -1                     -1
# 4                                -1                     -1
# 5                                -1                     -1
# 6                                -1                     -1
# ..                              ...                    ...
# 993                              -1                     -1
# 994                              -1                     -1
# 995                              -1                     -1
# 996                              -1                     -1
# 997                              -1                     -1
#
#                        Revenue  Competitors  Hourly  upd_salary  \
# 0    $25 to $100 million (USD)           -1       0    91036.00
# 1                           -1           -1       0   110000.00
# 4                           -1           -1       1       65.71
# 5                           -1           -1       0    96225.00
# 6                           -1           -1       0    62500.00
# ..                         ...          ...     ...         ...
# 993                         -1           -1       0   124950.00
# 994                         -1           -1       0   110000.00
# 995                         -1           -1       0   114296.00
# 996                         -1           -1       0   130867.00
# 997                         -1           -1       0    96225.00
#
#          Company text
# 0      BEN Group, Inc
# 1      Super Dispatch
# 4    Biometric Health
# 5       Vizient, Inc.
# 6    I28 Technologies
# ..                ...
# 993         Starbucks
# 994    Super Dispatch
# 995    Locus Robotics
# 996        Databricks
# 997     Vizient, Inc.
#
# [818 rows x 16 columns]

# %% [markdown]
# ### State field

# %%
# Getting the state abrev and putting it into another column
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1] if ',' in str(x) else x)
df.head(5)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company Name', 'Location',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'Hourly', 'upd_salary',
#        'Company text', 'job_state'],
#       dtype='object')

# %%
df_out = df.drop(['Headquarters', 'Founded', 'Industry', 'Sector', 'Revenue', 'Competitors'], axis=1 )

# %%
df_out.to_csv('glassdoor_data_cleaned.csv', index= False)

# %%
pd.read_csv('glassdoor_data_cleaned.csv')
# Out:
#                                         Job Title      Salary Estimate  \
# 0                   Data Scientist (Level I - II)   $91,036 /yr (est.)
# 1                                  Data Scientist  $110,000 /yr (est.)
# 2                                  Data Scientist    $65.71 /hr (est.)
# 3                        Data Scientist - Virtual   $96,225 /yr (est.)
# 4        Entry level Data Science Engineer-333338   $62,500 /yr (est.)
# ..                                            ...                  ...
# 813  data scientist, Operational Excellence - GSC  $124,950 /yr (est.)
# 814                                Data Scientist  $110,000 /yr (est.)
# 815              Data Scientist, Machine Learning  $114,296 /yr (est.)
# 816    Data Scientist / Machine Learning Engineer  $130,867 /yr (est.)
# 817                      Data Scientist - Virtual   $96,225 /yr (est.)
#
#      Rating           Company Name        Location                    Size  \
# 0       3.5    BEN Group, Inc\n3.5       Provo, UT    201 to 500 Employees
# 1       4.6    Super Dispatch\n4.6          Remote     51 to 200 Employees
# 2      -1.0       Biometric Health     Jackson, MS                 Unknown
# 3       4.2     Vizient, Inc.\n4.2          Remote  1001 to 5000 Employees
# 4       4.2  I28 Technologies\n4.2  Marysville, MI       1 to 50 Employees
# ..      ...                    ...             ...                     ...
# 813     3.7         Starbucks\n3.7     Seattle, WA        10000+ Employees
# 814     4.6    Super Dispatch\n4.6          Remote     51 to 200 Employees
# 815     5.0    Locus Robotics\n5.0  Wilmington, MA    201 to 500 Employees
# 816     4.6        Databricks\n4.6        West, TX  1001 to 5000 Employees
# 817     4.2     Vizient, Inc.\n4.2          Remote  1001 to 5000 Employees
#
#      Type of ownership  Hourly  upd_salary      Company text job_state
# 0    Company - Private       0    91036.00    BEN Group, Inc        UT
# 1    Company - Private       0   110000.00    Super Dispatch    Remote
# 2                   -1       1       65.71  Biometric Health        MS
# 3    Company - Private       0    96225.00     Vizient, Inc.    Remote
# 4    Company - Private       0    62500.00  I28 Technologies        MI
# ..                 ...     ...         ...               ...       ...
# 813                 -1       0   124950.00         Starbucks        WA
# 814  Company - Private       0   110000.00    Super Dispatch    Remote
# 815  Company - Private       0   114296.00    Locus Robotics        MA
# 816  Company - Private       0   130867.00        Databricks        TX
# 817  Company - Private       0    96225.00     Vizient, Inc.    Remote
#
# [818 rows x 11 columns]
